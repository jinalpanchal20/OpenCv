# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
image = cv.imread("shizuka.jpeg")
cv.imshow("d",image)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
kernel = np.ones((3,3))

# %%
kernel
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
image.shape
# Out:
# (224, 166, 3)

# %%
img1 = cv.resize(image,(180,120))
img_gray = cv.cvtColor(img1,cv.COLOR_BGR2GRAY)
#_,img_binary =  cv.threshold(img_gray, 200, 255, cv.THRESH_BINARY+cv.THRESH_OTSU)
img_binary_lp2 = cv.erode(img_gray,kernel)
img_binary_lp3 = cv.dilate(img_gray,kernel)

# %%
plt.imshow(img_gray_lp2)

# %%
plt.imshow(img_gray_lp3)

# %%
#edge detect
img1 = cv.Canny(image,255,255,(180,120))

img_binary_lp4 = cv.erode(img1,kernel)
img_binary_lp5 = cv.dilate(img1,kernel)

# %%
plt.imshow(img1)

# %%
plt.imshow(img_binary_lp4)

# %%
plt.imshow(img_binary_lp5)

# %%
img_binary_lp6 = cv.dilate(img_binary_lp5,kernel)

# %%
plt.imshow(img_binary_lp6)

# %%
img_binary_lp7 = cv.erode(img_binary_lp5,kernel)
plt.imshow(img_binary_lp7)
